# %%
from numpy import select
import pandas as pd
import duckdb
pd.set_option('display.max_columns', None)

chemin_fichier = r"retailcorps.parquet"

df=duckdb.query(f"""
    select *
    From read_parquet('{chemin_fichier}')
""").df()

# %%
display(df.tail(10))
# Out:
#         OrderLineID Invoice StockCode                            Description  \
# 1072697     1016248  578065     22807           SET OF 6 T-LIGHTS TOADSTOOLS
# 1072698     1045002  580152     22613            PACK OF 20 SPACEBOY NAPKINS
# 1072699     1064326  581419     23292                 SPACEBOY CHILDRENS CUP
# 1072700     1039727  579690     22734    SET OF 6 RIBBONS VINTAGE CHRISTMAS
# 1072701     1038571  579535     20668        DISCO BALL CHRISTMAS DECORATION
# 1072702     1033960  579196     21070                 VINTAGE BILLBOARD MUG
# 1072703     1062960  581310     16238              PARTY TIME PENCIL ERASERS
# 1072704     1033416  579188     22139       RETROSPOT TEA SET CERAMIC 11 PC
# 1072705     1001514  576932     22086        PAPER CHAIN KIT 50'S CHRISTMAS
# 1072706     1035637  579432     85203       HANGING WOOD AND FELT BUTTERFLY
#
#         Quantity          InvoiceDate CustomerID         Country  \
# 1072697        1  2011-11-22 15:41:00        NaN  United Kingdom
# 1072698       12  2011-12-02 10:22:00    12364.0         Belgium
# 1072699        8  2011-12-08 15:03:00    15484.0  United Kingdom
# 1072700        2  2011-11-30 14:03:00    15060.0  United Kingdom
# 1072701       24  2011-11-30 09:50:00    15414.0  United Kingdom
# 1072702        1  2011-11-28 15:54:00    14096.0  United Kingdom
# 1072703        1  2011-12-08 11:43:00    16442.0  United Kingdom
# 1072704        4  2011-11-28 15:34:00    12748.0  United Kingdom
# 1072705        5  2011-11-17 11:12:00    15443.0  United Kingdom
# 1072706        8  2011-11-29 13:12:00    15311.0  United Kingdom
#
#         ProductCategoryCode  ProductCategory ProductFamily  \
# 1072697                HOME  Home decoration      Interior
# 1072698               OTHER            Other         Other
# 1072699               CHILD         Children     Occasions
# 1072700            SEASONAL         Seasonal     Occasions
# 1072701            SEASONAL         Seasonal     Occasions
# 1072702             KITCHEN      Kitchenware      Interior
# 1072703          STATIONERY       Stationery        Office
# 1072704             KITCHEN      Kitchenware      Interior
# 1072705            SEASONAL         Seasonal     Occasions
# 1072706               OTHER            Other         Other
#
#                            ProductNameClean UnitPriceGBP UnitCostGBP  \
# 1072697        Set Of 6 T-Lights Toadstools        14.26        6.66
# 1072698         Pack Of 20 Spaceboy Napkins         4.75        2.99
# 1072699              Spaceboy Childrens Cup        19.47        8.21
# 1072700  Set Of 6 Ribbons Vintage Christmas        13.11         6.0
# 1072701     Disco Ball Christmas Decoration        36.09       19.76
# 1072702               Vintage Billboard Mug        29.53        14.3
# 1072703           Party Time Pencil Erasers         1.84        0.63
# 1072704     Retrospot Tea Set Ceramic 11 Pc        28.42       13.91
# 1072705      Paper Chain Kit 50'S Christmas        10.57        3.06
# 1072706     Hanging Wood And Felt Butterfly        12.11        5.37
#
#         CustomerSegment    CustomerType LoyaltyProgram SalesChannel  \
# 1072697             VIP        Retailer           Gold        Phone
# 1072698       Low value        Retailer             No       Online
# 1072699         Regular        Retailer         Bronze        Store
# 1072700           Loyal  Small business         Silver        Store
# 1072701           Loyal        Retailer         Silver  Marketplace
# 1072702             VIP        Retailer           Gold        Phone
# 1072703             VIP  Small business           Gold        Store
# 1072704       Low value        Retailer             No        Phone
# 1072705         Regular      Individual         Bronze  Marketplace
# 1072706             VIP        Retailer           Gold       Online
#
#          PaymentMethod WarehouseID PromotionCode DiscountRate OrderStatus  \
# 1072697        Invoice    WH-UK-02          NONE          0.0   Completed
# 1072698           Card    WH-EU-01          XMAS         0.15   Completed
# 1072699  Bank transfer    WH-UK-01     CLEARANCE          0.2   Completed
# 1072700  Bank transfer    WH-UK-01          XMAS         0.15   Completed
# 1072701         PayPal    WH-UK-02          XMAS         0.15   Cancelled
# 1072702        Invoice    WH-UK-02     WELCOME10          0.1   Cancelled
# 1072703  Bank transfer    WH-UK-01          NONE          0.0   Completed
# 1072704        Invoice    WH-UK-02     WELCOME10          0.1   Completed
# 1072705         PayPal    WH-UK-02          NONE          0.0   Completed
# 1072706           Card    WH-UK-01          XMAS         0.15   Completed
#
#         DeliveryTime Continent          Region Currency
# 1072697           15    Europe  Western Europe      GBP
# 1072698           15    Europe  Western Europe      EUR
# 1072699            6    Europe  Western Europe      GBP
# 1072700            1    Europe  Western Europe      GBP
# 1072701            2    Europe  Western Europe      GBP
# 1072702           10    Europe  Western Europe      GBP
# 1072703            8    Europe  Western Europe      GBP
# 1072704           15    Europe  Western Europe      GBP
# 1072705            9    Europe  Western Europe      GBP
# 1072706           11    Europe  Western Europe      GBP

# %%
def explorer_dataset(dataset):
        print(f"Start {'-'*10} Pour ce dataset, la taille est de {dataset.shape} {'-'*10}")
        print('-'*30)
        display(dataset.head(3))
        print('-'*30)
        display(dataset.tail(3))
        print('-'*30)
        print(f"Présences de valeurs 'NaN'.")
        print(f"{dataset.isna().sum()}")
        display(dataset[dataset.isna().any(axis=1)])
        print('-'*30)
        print(f"Les doublons")
        print(f"{dataset.duplicated().sum()}")
        print('-'*30)
        print(f"Les types de données")
        print(f"{dataset.dtypes}")
        print('-'*30)
        print(f"Description")
        display(dataset.describe().T)
        print("FIN"+'-'*100)

# %%
explorer_dataset(df)
# Out:
# Start ---------- Pour ce dataset, la taille est de (1072707, 27) ----------
# ------------------------------
#   OrderLineID Invoice StockCode                          Description Quantity  \
# 0           1  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1           2  489434    79323P                   PINK CHERRY LIGHTS       12
# 2           3  489434    79323W                  WHITE CHERRY LIGHTS       12
#
#            InvoiceDate CustomerID         Country ProductCategoryCode  \
# 0  2009-12-01 07:45:00    13085.0  United Kingdom            SEASONAL
# 1  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
# 2  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
#
#    ProductCategory ProductFamily                     ProductNameClean  \
# 0         Seasonal     Occasions  15Cm Christmas Glass Ball 20 Lights
# 1  Home decoration      Interior                   Pink Cherry Lights
# 2  Home decoration      Interior                  White Cherry Lights
#
#   UnitPriceGBP UnitCostGBP CustomerSegment    CustomerType LoyaltyProgram  \
# 0        17.82        8.47         Regular  Small business         Bronze
# 1        21.29       11.43         Regular  Small business         Bronze
# 2          7.2         2.6         Regular  Small business         Bronze
#
#   SalesChannel PaymentMethod WarehouseID PromotionCode DiscountRate  \
# 0       Online          Card    WH-UK-01          NONE          0.0
# 1       Online          Card    WH-UK-01          NONE          0.0
# 2       Online          Card    WH-UK-01          NONE          0.0
#
#   OrderStatus DeliveryTime Continent          Region Currency
# 0   Completed           11    Europe  Western Europe      GBP
# 1   Completed           11    Europe  Western Europe      GBP
# 2   Completed           11    Europe  Western Europe      GBP
# ------------------------------
#         OrderLineID Invoice StockCode                       Description  \
# 1072704     1033416  579188     22139  RETROSPOT TEA SET CERAMIC 11 PC
# 1072705     1001514  576932     22086   PAPER CHAIN KIT 50'S CHRISTMAS
# 1072706     1035637  579432     85203  HANGING WOOD AND FELT BUTTERFLY
#
#         Quantity          InvoiceDate CustomerID         Country  \
# 1072704        4  2011-11-28 15:34:00    12748.0  United Kingdom
# 1072705        5  2011-11-17 11:12:00    15443.0  United Kingdom
# 1072706        8  2011-11-29 13:12:00    15311.0  United Kingdom
#
#         ProductCategoryCode ProductCategory ProductFamily  \
# 1072704             KITCHEN     Kitchenware      Interior
# 1072705            SEASONAL        Seasonal     Occasions
# 1072706               OTHER           Other         Other
#
#                         ProductNameClean UnitPriceGBP UnitCostGBP  \
# 1072704  Retrospot Tea Set Ceramic 11 Pc        28.42       13.91
# 1072705   Paper Chain Kit 50'S Christmas        10.57        3.06
# 1072706  Hanging Wood And Felt Butterfly        12.11        5.37
#
#         CustomerSegment CustomerType LoyaltyProgram SalesChannel  \
# 1072704       Low value     Retailer             No        Phone
# 1072705         Regular   Individual         Bronze  Marketplace
# 1072706             VIP     Retailer           Gold       Online
#
#         PaymentMethod WarehouseID PromotionCode DiscountRate OrderStatus  \
# 1072704       Invoice    WH-UK-02     WELCOME10          0.1   Completed
# 1072705        PayPal    WH-UK-02          NONE          0.0   Completed
# 1072706          Card    WH-UK-01          XMAS         0.15   Completed
#
#         DeliveryTime Continent          Region Currency
# 1072704           15    Europe  Western Europe      GBP
# 1072705            9    Europe  Western Europe      GBP
# 1072706           11    Europe  Western Europe      GBP
# ------------------------------
# Présences de valeurs 'NaN'.
# OrderLineID                 0
# Invoice                     0
# StockCode                   0
# Description             12993
# Quantity                    0
# InvoiceDate                 0
# CustomerID             254201
# Country                     0
# ProductCategoryCode      3226
# ProductCategory          4342
# ProductFamily               0
# ProductNameClean         4405
# UnitPriceGBP                0
# UnitCostGBP              1044
# CustomerSegment             0
# CustomerType                0
# LoyaltyProgram              0
# SalesChannel             4195
# PaymentMethod               0
# WarehouseID              1775
# PromotionCode            1777
# DiscountRate              636
# OrderStatus              1334
# DeliveryTime              815
# Continent                   0
# Region                      0
# Currency                 1673
# dtype: int64
#         OrderLineID Invoice StockCode                         Description  \
# 31               32  489437     22143   CHRISTMAS CRAFT HEART DECORATIONS
# 45               46  489437     21989      PACK OF 20 SKULL PAPER NAPKINS
# 120             121  489443     21035        SET/2 RED SPOTTY TEA TOWELS
# 126             127  489444      POST                             POSTAGE
# 146             147  489446     21733    RED HANGING HEART T-LIGHT HOLDER
# ...             ...     ...       ...                                 ...
# 1072684     1034618  579297     21191  LARGE WHITE HONEYCOMB PAPER BELL
# 1072693     1046889  580366     23393      HOME SWEET HOME CUSHION COVER
# 1072695     1040396  579751     22697     GREEN REGENCY TEACUP AND SAUCER
# 1072696     1039841  579694     21165       BEWARE OF THE CAT METAL SIGN
# 1072697     1016248  578065     22807        SET OF 6 T-LIGHTS TOADSTOOLS
#
#         Quantity          InvoiceDate CustomerID         Country  \
# 31             6  2009-12-01 09:08:00        NaN  United Kingdom
# 45            12  2009-12-01 09:08:00    15362.0  United Kingdom
# 120           12  2009-12-01 09:50:00        NaN  United Kingdom
# 126            1  2009-12-01 09:55:00    12636.0             USA
# 146           32  2009-12-01 10:06:00    13758.0  United Kingdom
# ...          ...                  ...        ...             ...
# 1072684        4  2011-11-29 11:23:00        NaN  United Kingdom
# 1072693        2  2011-12-02 16:38:00        NaN  United Kingdom
# 1072695        4  2011-11-30 14:46:00        NaN  United Kingdom
# 1072696        2  2011-11-30 14:11:00        NaN  United Kingdom
# 1072697        1  2011-11-22 15:41:00        NaN  United Kingdom
#
#         ProductCategoryCode  ProductCategory ProductFamily  \
# 31                 SEASONAL         Seasonal     Occasions
# 45               STATIONERY              NaN        Office
# 120                 KITCHEN      Kitchenware      Interior
# 126                   OTHER            Other         Other
# 146                    HOME              NaN      Interior
# ...                     ...              ...           ...
# 1072684          STATIONERY       Stationery        Office
# 1072693               OTHER            Other         Other
# 1072695             KITCHEN      Kitchenware      Interior
# 1072696                HOME  Home decoration      Interior
# 1072697                HOME  Home decoration      Interior
#
#                           ProductNameClean UnitPriceGBP UnitCostGBP  \
# 31       Christmas Craft Heart Decorations        11.81        6.12
# 45          Pack Of 20 Skull Paper Napkins         1.85        0.64
# 120            Set/2 Red Spotty Tea Towels        34.49       18.32
# 126                                Postage         1.13        0.54
# 146       Red Hanging Heart T-Light Holder            0         2.4
# ...                                    ...          ...         ...
# 1072684   Large White Honeycomb Paper Bell         4.31        1.57
# 1072693      Home Sweet Home Cushion Cover         5.02        2.04
# 1072695    Green Regency Teacup And Saucer        30.23       18.27
# 1072696       Beware Of The Cat Metal Sign        13,12        5.47
# 1072697       Set Of 6 T-Lights Toadstools        14.26        6.66
#
#         CustomerSegment CustomerType LoyaltyProgram SalesChannel  \
# 31              Regular     Retailer         Bronze  Marketplace
# 45              Regular     Retailer         Bronze  Marketplace
# 120               Loyal   Individual         Silver        Phone
# 126           Low value   Individual             No          NaN
# 146           Low value   Individual             No       Online
# ...                 ...          ...            ...          ...
# 1072684             VIP     Retailer           Gold  Marketplace
# 1072693             VIP     Retailer           Gold  Marketplace
# 1072695             VIP     Retailer           Gold  Marketplace
# 1072696             VIP     Retailer           Gold        Store
# 1072697             VIP     Retailer           Gold        Phone
#
#          PaymentMethod WarehouseID PromotionCode DiscountRate OrderStatus  \
# 31              PayPal    WH-UK-02     CLEARANCE          0.2   Completed
# 45              PayPal    WH-UK-02     CLEARANCE          0.2   Completed
# 120            Invoice    WH-UK-02     WELCOME10          0.1   Completed
# 126               Card    WH-NA-01     WELCOME10          0.1   Completed
# 146               Card    WH-UK-01          NONE          0.0   Completed
# ...                ...         ...           ...          ...         ...
# 1072684         PayPal    WH-UK-02          NONE          0.0   Completed
# 1072693         PayPal    WH-UK-02          XMAS         0.15   Completed
# 1072695         PayPal    WH-UK-02     WELCOME10          0.1   Completed
# 1072696  Bank transfer    WH-UK-01        SPRING         0.05   Completed
# 1072697        Invoice    WH-UK-02          NONE          0.0   Completed
#
#         DeliveryTime      Continent          Region Currency
# 31                15         Europe  Western Europe      GBP
# 45                15         Europe  Western Europe      GBP
# 120                2         Europe  Western Europe      GBP
# 126                4  North America   North America      USD
# 146               11         Europe  Western Europe      GBP
# ...              ...            ...             ...      ...
# 1072684           14         Europe  Western Europe      GBP
# 1072693           12         Europe  Western Europe      GBP
# 1072695            9         Europe  Western Europe      GBP
# 1072696           15         Europe  Western Europe      GBP
# 1072697           15         Europe  Western Europe      GBP
#
# [276342 rows x 27 columns]
# ------------------------------
# Les doublons
