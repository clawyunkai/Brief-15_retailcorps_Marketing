# %%
from numpy import select
import pandas as pd
import duckdb
pd.set_option('display.max_columns', None)

df=duckdb.query("""
    select *
    From read_csv_auto('retailcorps.csv', all_varchar=true)
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
display(df.head(10))
# Out:
#   OrderLineID Invoice StockCode                          Description Quantity  \
# 0           1  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1           2  489434    79323P                   PINK CHERRY LIGHTS       12
# 2           3  489434    79323W                  WHITE CHERRY LIGHTS       12
# 3           4  489434     22041         RECORD FRAME 7" SINGLE SIZE        48
# 4           5  489434     21232       STRAWBERRY CERAMIC TRINKET BOX       24
# 5           6  489434     22064           PINK DOUGHNUT TRINKET POT        24
# 6           7  489434     21871                  SAVE THE PLANET MUG       24
# 7           8  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT       10
# 8           9  489435     22350                            CAT BOWL        12
# 9          10  489435     22349       DOG BOWL , CHASING BALL DESIGN       12
#
#            InvoiceDate CustomerID         Country ProductCategoryCode  \
# 0  2009-12-01 07:45:00    13085.0  United Kingdom            SEASONAL
# 1  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
# 2  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
# 3  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
# 4  2009-12-01 07:45:00    13085.0  United Kingdom               OTHER
# 5  2009-12-01 07:45:00    13085.0  United Kingdom               OTHER
# 6  2009-12-01 07:45:00    13085.0  United Kingdom             KITCHEN
# 7  2009-12-01 07:45:00    13085.0  United Kingdom               OTHER
# 8  2009-12-01 07:46:00    13085.0  United Kingdom             KITCHEN
# 9  2009-12-01 07:46:00    13085.0  United Kingdom             KITCHEN
#
#    ProductCategory ProductFamily                     ProductNameClean  \
# 0         Seasonal     Occasions  15Cm Christmas Glass Ball 20 Lights
# 1  Home decoration      Interior                   Pink Cherry Lights
# 2  Home decoration      Interior                  White Cherry Lights
# 3  Home decoration      Interior          Record Frame 7" Single Size
# 4            Other         Other       Strawberry Ceramic Trinket Box
# 5            Other         Other            Pink Doughnut Trinket Pot
# 6      Kitchenware      Interior                  Save The Planet Mug
# 7            Other         Other   Fancy Font Home Sweet Home Doormat
# 8      Kitchenware      Interior                             Cat Bowl
# 9      Kitchenware      Interior       Dog Bowl , Chasing Ball Design
#
#   UnitPriceGBP UnitCostGBP CustomerSegment    CustomerType LoyaltyProgram  \
# 0        17.82        8.47         Regular  Small business         Bronze
# 1        21.29       11.43         Regular  Small business         Bronze
# 2          7.2         2.6         Regular  Small business         Bronze
# 3        21.15       11.45         Regular  Small business         Bronze
# 4        12.74        5.85         Regular  Small business         Bronze
# 5        10.44        6.29         Regular  Small business         Bronze
# 6         28.0       18.89         Regular  Small business         Bronze
# 7        10.26        3.96         Regular  Small business         Bronze
# 8        19.65        8.12         Regular  Small business         Bronze
# 9         13.3        8.97         Regular  Small business         Bronze
#
#   SalesChannel PaymentMethod WarehouseID PromotionCode DiscountRate  \
# 0       Online          Card    WH-UK-01          NONE          0.0
# 1       Online          Card    WH-UK-01          NONE          0.0
# 2       Online          Card    WH-UK-01          NONE          0.0
# 3       Online          Card    WH-UK-01          NONE          0.0
# 4       Online          Card    WH-UK-01          NONE          0.0
# 5       Online          Card    WH-UK-01          NONE          0.0
# 6       Online          Card    WH-UK-01          NONE          0.0
# 7       Online          Card    WH-UK-01          NONE          0.0
# 8        Phone       Invoice    WH-UK-02          XMAS         0.15
# 9        Phone       Invoice    WH-UK-02          XMAS         0.15
#
#   OrderStatus DeliveryTime Continent          Region Currency
# 0   Completed           11    Europe  Western Europe      GBP
# 1   Completed           11    Europe  Western Europe      GBP
# 2   Completed           11    Europe  Western Europe      GBP
# 3   Completed           11    Europe  Western Europe      GBP
# 4   Completed           11    Europe  Western Europe      GBP
# 5   Completed           11    Europe  Western Europe      GBP
# 6   Completed           11    Europe  Western Europe      GBP
# 7   Completed           11    Europe  Western Europe      GBP
# 8   Completed            9    Europe  Western Europe      GBP
# 9   Completed            9    Europe  Western Europe      GBP

# %%
duckdb.query("""
COPY(
    SELECT * FROM df
)
TO 'retailcorps.parquet'
(FORMAT PARQUET)
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
def explorer_dataset(dataset):
        print(f"Start {'-'*10} Pour ce dataset, la taille est de {dataset.shape} {'-'*10}")
        print('-'*30)
        display(dataset.head(3))
        print('-'*30)
        display(dataset.tail(3))
        print('-'*30)
        print(f"Présences de valeurs 'NaN'.")
        print(f"{dataset.isna().sum()}")
        display(dataset[dataset.isna().any(axis=1)])
        print('-'*30)
        print(f"Les doublons")
        print(f"{dataset.duplicated().sum()}")
        print('-'*30)
        print(f"Les types de données")
        print(f"{dataset.dtypes}")
        print('-'*30)
        print(f"Description")
        display(dataset.describe().T)
        print("FIN"+'-'*100)

# %%
explorer_dataset(df)
# Out:
# Start ---------- Pour ce dataset, la taille est de (1072707, 27) ----------
# ------------------------------
#   OrderLineID Invoice StockCode                          Description Quantity  \
# 0           1  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1           2  489434    79323P                   PINK CHERRY LIGHTS       12
# 2           3  489434    79323W                  WHITE CHERRY LIGHTS       12
#
#            InvoiceDate CustomerID         Country ProductCategoryCode  \
# 0  2009-12-01 07:45:00    13085.0  United Kingdom            SEASONAL
# 1  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
# 2  2009-12-01 07:45:00    13085.0  United Kingdom                HOME
#
#    ProductCategory  ... SalesChannel PaymentMethod WarehouseID PromotionCode  \
# 0         Seasonal  ...       Online          Card    WH-UK-01          NONE
# 1  Home decoration  ...       Online          Card    WH-UK-01          NONE
# 2  Home decoration  ...       Online          Card    WH-UK-01          NONE
#
#   DiscountRate OrderStatus DeliveryTime Continent          Region Currency
# 0          0.0   Completed           11    Europe  Western Europe      GBP
# 1          0.0   Completed           11    Europe  Western Europe      GBP
# 2          0.0   Completed           11    Europe  Western Europe      GBP
#
# [3 rows x 27 columns]
# ------------------------------
#         OrderLineID Invoice StockCode                       Description  \
# 1072704     1033416  579188     22139  RETROSPOT TEA SET CERAMIC 11 PC
# 1072705     1001514  576932     22086   PAPER CHAIN KIT 50'S CHRISTMAS
# 1072706     1035637  579432     85203  HANGING WOOD AND FELT BUTTERFLY
#
#         Quantity          InvoiceDate CustomerID         Country  \
# 1072704        4  2011-11-28 15:34:00    12748.0  United Kingdom
# 1072705        5  2011-11-17 11:12:00    15443.0  United Kingdom
# 1072706        8  2011-11-29 13:12:00    15311.0  United Kingdom
#
#         ProductCategoryCode ProductCategory  ... SalesChannel PaymentMethod  \
# 1072704             KITCHEN     Kitchenware  ...        Phone       Invoice
# 1072705            SEASONAL        Seasonal  ...  Marketplace        PayPal
# 1072706               OTHER           Other  ...       Online          Card
#
#         WarehouseID PromotionCode DiscountRate OrderStatus DeliveryTime  \
# 1072704    WH-UK-02     WELCOME10          0.1   Completed           15
# 1072705    WH-UK-02          NONE          0.0   Completed            9
# 1072706    WH-UK-01          XMAS         0.15   Completed           11
#
#         Continent          Region Currency
# 1072704    Europe  Western Europe      GBP
# 1072705    Europe  Western Europe      GBP
# 1072706    Europe  Western Europe      GBP
#
# [3 rows x 27 columns]
# ------------------------------
# Présences de valeurs 'NaN'.
# OrderLineID                 0
# Invoice                     0
# StockCode                   0
# Description             12993
# Quantity                    0
# InvoiceDate                 0
# CustomerID             254201
# Country                     0
# ProductCategoryCode      3226
# ProductCategory          4342
# ProductFamily               0
# ProductNameClean         4405
# UnitPriceGBP                0
# UnitCostGBP              1044
# CustomerSegment             0
# CustomerType                0
# LoyaltyProgram              0
# SalesChannel             4195
# PaymentMethod               0
# WarehouseID              1775
# PromotionCode            1777
# DiscountRate              636
# OrderStatus              1334
# DeliveryTime              815
# Continent                   0
# Region                      0
# Currency                 1673
# dtype: int64
#         OrderLineID Invoice StockCode                         Description  \
# 31               32  489437     22143   CHRISTMAS CRAFT HEART DECORATIONS
# 45               46  489437     21989      PACK OF 20 SKULL PAPER NAPKINS
# 120             121  489443     21035        SET/2 RED SPOTTY TEA TOWELS
# 126             127  489444      POST                             POSTAGE
# 146             147  489446     21733    RED HANGING HEART T-LIGHT HOLDER
# ...             ...     ...       ...                                 ...
# 1072684     1034618  579297     21191  LARGE WHITE HONEYCOMB PAPER BELL
# 1072693     1046889  580366     23393      HOME SWEET HOME CUSHION COVER
# 1072695     1040396  579751     22697     GREEN REGENCY TEACUP AND SAUCER
# 1072696     1039841  579694     21165       BEWARE OF THE CAT METAL SIGN
# 1072697     1016248  578065     22807        SET OF 6 T-LIGHTS TOADSTOOLS
#
#         Quantity          InvoiceDate CustomerID         Country  \
# 31             6  2009-12-01 09:08:00       None  United Kingdom
# 45            12  2009-12-01 09:08:00    15362.0  United Kingdom
# 120           12  2009-12-01 09:50:00       None  United Kingdom
# 126            1  2009-12-01 09:55:00    12636.0             USA
# 146           32  2009-12-01 10:06:00    13758.0  United Kingdom
# ...          ...                  ...        ...             ...
# 1072684        4  2011-11-29 11:23:00       None  United Kingdom
# 1072693        2  2011-12-02 16:38:00       None  United Kingdom
# 1072695        4  2011-11-30 14:46:00       None  United Kingdom
# 1072696        2  2011-11-30 14:11:00       None  United Kingdom
# 1072697        1  2011-11-22 15:41:00       None  United Kingdom
#
#         ProductCategoryCode  ProductCategory  ... SalesChannel  PaymentMethod  \
# 31                 SEASONAL         Seasonal  ...  Marketplace         PayPal
# 45               STATIONERY             None  ...  Marketplace         PayPal
# 120                 KITCHEN      Kitchenware  ...        Phone        Invoice
# 126                   OTHER            Other  ...         None           Card
# 146                    HOME             None  ...       Online           Card
# ...                     ...              ...  ...          ...            ...
# 1072684          STATIONERY       Stationery  ...  Marketplace         PayPal
# 1072693               OTHER            Other  ...  Marketplace         PayPal
# 1072695             KITCHEN      Kitchenware  ...  Marketplace         PayPal
# 1072696                HOME  Home decoration  ...        Store  Bank transfer
# 1072697                HOME  Home decoration  ...        Phone        Invoice
#
#         WarehouseID PromotionCode DiscountRate OrderStatus DeliveryTime  \
# 31         WH-UK-02     CLEARANCE          0.2   Completed           15
# 45         WH-UK-02     CLEARANCE          0.2   Completed           15
# 120        WH-UK-02     WELCOME10          0.1   Completed            2
# 126        WH-NA-01     WELCOME10          0.1   Completed            4
# 146        WH-UK-01          NONE          0.0   Completed           11
# ...             ...           ...          ...         ...          ...
# 1072684    WH-UK-02          NONE          0.0   Completed           14
# 1072693    WH-UK-02          XMAS         0.15   Completed           12
# 1072695    WH-UK-02     WELCOME10          0.1   Completed            9
# 1072696    WH-UK-01        SPRING         0.05   Completed           15
# 1072697    WH-UK-02          NONE          0.0   Completed           15
#
#              Continent          Region Currency
# 31              Europe  Western Europe      GBP
# 45              Europe  Western Europe      GBP
# 120             Europe  Western Europe      GBP
# 126      North America   North America      USD
# 146             Europe  Western Europe      GBP
# ...                ...             ...      ...
# 1072684         Europe  Western Europe      GBP
# 1072693         Europe  Western Europe      GBP
# 1072695         Europe  Western Europe      GBP
# 1072696         Europe  Western Europe      GBP
# 1072697         Europe  Western Europe      GBP
#
# [276342 rows x 27 columns]
# ------------------------------
# Les doublons
# 5336
# ------------------------------
# Les types de données
# OrderLineID            object
# Invoice                object
# StockCode              object
# Description            object
# Quantity               object
# InvoiceDate            object
# CustomerID             object
# Country                object
# ProductCategoryCode    object
# ProductCategory        object
# ProductFamily          object
# ProductNameClean       object
# UnitPriceGBP           object
# UnitCostGBP            object
# CustomerSegment        object
# CustomerType           object
# LoyaltyProgram         object
# SalesChannel           object
# PaymentMethod          object
# WarehouseID            object
# PromotionCode          object
# DiscountRate           object
# OrderStatus            object
# DeliveryTime           object
# Continent              object
# Region                 object
# Currency               object
# dtype: object
# ------------------------------
# Description
#                        count   unique                                 top  \
# OrderLineID          1072707  1067371                             1004179
# Invoice              1072707    53628                              537434
# StockCode            1072707     5619                              85123A
# Description          1059714     9081  WHITE HANGING HEART T-LIGHT HOLDER
# Quantity             1072707     1150                                   1
# InvoiceDate          1072707    55180                 2010-12-06 16:57:00
# CustomerID            818506     5942                             17841.0
# Country              1072707       61                      United Kingdom
# ProductCategoryCode  1069481        7                               OTHER
# ProductCategory      1068365       14                               Other
# ProductFamily        1072707        4                               Other
# ProductNameClean     1068302     5620  White Hanging Heart T-Light Holder
# UnitPriceGBP         1072707     4348                               14.47
# UnitCostGBP          1071663     2611                                7.81
# CustomerSegment      1072707        4                                 VIP
# CustomerType         1072707        3                            Retailer
# LoyaltyProgram       1072707        4                                Gold
# SalesChannel         1068512        4                         Marketplace
# PaymentMethod        1072707        4                              PayPal
# WarehouseID          1070932        9                            WH-UK-01
# PromotionCode        1070930        5                              SPRING
# DiscountRate         1072071        6                                0.05
# OrderStatus          1071373        3                           Completed
# DeliveryTime         1071892       19                                  15
# Continent            1072707        6                              Europe
# Region               1072707       11                      Western Europe
# Currency             1071034       15                                 GBP
#
#                         freq
# OrderLineID                2
# Invoice                 1355
# StockCode               5806
# Description             5806
# Quantity              294104
# InvoiceDate             1337
# CustomerID             13009
# Country               974714
# ProductCategoryCode   453268
# ProductCategory       450561
# ProductFamily         454629
# ProductNameClean        5948
# UnitPriceGBP            6074
# UnitCostGBP             7656
# CustomerSegment       449187
# CustomerType          531853
# LoyaltyProgram        449187
# SalesChannel          271975
# PaymentMethod         273029
# WarehouseID           495246
# PromotionCode         222852
# DiscountRate          222864
# OrderStatus           942487
# DeliveryTime           76253
# Continent            1067806
# Region               1054930
# Currency              988647
# FIN----------------------------------------------------------------------------------------------------
